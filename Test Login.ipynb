# %%
import requests

# %%
def post(suffix, query_params=None, body=None, data=None, headers=None):
    if query_params is not None:
        warnings.warn("query_params to be renamed body, use body to futureproof")
        body = query_params

    return main.__SESSION__.post(
        endpoint(suffix),
        json=body,
        data=data,
        headers=headers
    )

# %%
session = requests.session()

# %%
response = session.post(
    endpoint("login"),
    json={
        "username": "dibidave",
        "password": None
    }
)

# %%
response = session.get(
    endpoint(
        "logs",
        {
            "age": 60
        }
    )
)

logs = response.json()["logs"]

print(f"Num logs: {len(logs)}")

# %%
for inter
